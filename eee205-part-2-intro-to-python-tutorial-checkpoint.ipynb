# %% [markdown]
# ## EE205 Artificial Intelligence I
# # Part 2 - Intro to Python
# ## Tutorial
# ### Barry Dillon

# %% [markdown]
# In this tutorial you'll complete 40 questions related to the material in the Intro to Python lecture.  There are some additional concepts in here that weren't covered in the lecture.  You can use the internet to look up anything you're unsure of.  W3Schools is a great resource:  https://www.w3schools.com/python/
#
# **Do not use generative AI to solve these problems, or any problems set during tutorials**.  GenAI is a great tool, and we will cover how to use it effectively for learning during this course.  But using it to solve tutorial problems like this will only hinder your learning.

# %% [markdown]
# Q1. Use the built-in function `len()` to find the length of the string `'PythonProgramming'`.

# %%
text = "PythonProgramming"
print("Length of string: ", len(text))
# Out:
# Length of string:  17

# %% [markdown]
# Q2. The code below uses a built-in function incorrectly. Fix the error.
#
# ```python
# print(Len([1,2,3,4]))
# ```

# %%
print(len([1,2,3,4]))

#or

my_list = [1,2,3,4]
print(len(my_list))
# Out:
# 4
# 4

# %% [markdown]
# Q3. Use the built-in function `max()` to find the largest number in the list `[10, 45, 2, 99, 23]`.

# %%
max(10, 45, 2, 99, 23)
# Out:
# 99

# %% [markdown]
# Q4. Use the built-in function `round()` to round the number `12.34567` to 2 decimal places.

# %%
round(12.34567, 2)
# Out:
# 12.35

# %% [markdown]
# Q5. The following code has an error. Fix it so it correctly converts a string to an integer.
#
# ```python
# num = int('12a')
# ```

# %%
num = int("12")
print(num)
# Out:
# 12

# %% [markdown]
# Q6. Is `while` a Python keyword or not?  Explain.

# %% [markdown]
# Yes, it's the name of a loop and can't be used as the name of a variable.

# %% [markdown]
# Q7. The code below has an error, what is it?
#
# ```python
# for = 10
# ```

# %% [markdown]
# 'for' can only be used as a loop, not as a variable name, since it's a keyword in Python.

# %% [markdown]
# Q8. List any 5 Python keywords.

# %%
while, for, if, elif, else

# %% [markdown]
# Q9. The code below has a syntax error due to keyword misuse. Fix it and run the code.
#
# ```python
# if True:
#     print('Yes')
# Else:
#     print('No')
# ```

# %%
if True:
    print('Yes')
else:
    print('No')
# Out:
# Yes

# %% [markdown]
# Q10. Write a short explanation of why you cannot redefine keywords in Python.

# %% [markdown]
# You will get a syntax error

# %% [markdown]
# Q11. Assign the value `25` to a variable called `age`.

# %%
age = 25

# %% [markdown]
# Q12. What is wrong with this variable assignment? Fix it.
#
# ```python
# 2name = 'Alice'
# ```

# %%
name = "Alice"
print(name)
# Out:
# Alice

# %% [markdown]
# Q13. Assign multiple values `1, 2, 3` to variables `x, y, z` in one line.

# %%
x, y, z = 1, 2, 3

# %% [markdown]
# Q14. Swap the values of two variables `a = 5` and `b = 10` without using a temporary variable.

# %%
a, b = 5, 10
a, b = b, a
print(a , b)
# Out:
# 10 5

# %% [markdown]
# Q15. What is the data type of `3.14` in Python? Confirm it using `type()`.

# %%
#float
num = 3.14
print(type(num))
# Out:
# <class 'float'>

# %% [markdown]
# Q16. Convert the integer `10` into a string.

# %%
num = 10
string = str(num)
print(string)
# Out:
# 10

# %% [markdown]
# Q17. Predict the output type of the following code:
#
# ```python
# result = 3 + 2.0
# print(type(result))
# ```

# %%
<class 'float'>

# %% [markdown]
# Why is the result what it is?

# %% [markdown]
# It's a decimal number, making it a float

# %% [markdown]
# Q18. Fix the error in the following code:
#
# ```python
# value = int('3.5')
# ```

# %%
value = 3.5

# %% [markdown]
# Q19. Create a list called `fruits` containing `'apple', 9091, 1.2`.

# %%
fruits = ['apple', 9091, 1.2]

# %% [markdown]
# Q20. Access the second element of the list `numbers = [10, 20, 30, 40]`.

# %%
fruits = ['apple', 9091, 1.2]
print(fruits[1])
# Out:
# 9091

# %% [markdown]
# Q21. Add `'orange'` to the list `fruits = ['apple', 'banana']`.

# %%
fruits = ['apple', 'banana']
fruits.append('orange')
print(fruits)
# Out:
# ['apple', 'banana', 'orange']

# %% [markdown]
# Q22. Fix the error in the following code:
#
# ```python
# mylist = [1, 2, 3]
# print(mylist[3])
# ```

# %%
mylist = [1, 2, 3]
print(mylist[2])
# Out:
# 3

# %% [markdown]
# Explain the error.

# %% [markdown]
# there is no fourth item inside the list, [3] is out of range

# %% [markdown]
# Q23. Use list slicing to get the first 3 elements of `nums = [5,6,7,8,9]`.

# %%
nums = [5, 6, 7, 8, 9]
print(nums[:3])
# Out:
# [5, 6, 7]

# %% [markdown]
# Q24. Create a dictionary called `student` with keys `'name'` and `'age'`, values `'Alice'` and `20`.

# %%
student = {"name": "Alice", "age": "20"}

# %% [markdown]
# Q25. Access the value associated with the key `'age'` in `student = {'name':'Bob', 'age':25}`.

# %%
student = {'name':'Bob', 'age':25}
student['age']
# Out:
# 25

# %% [markdown]
# Q26. Fix the error in the dictionary below.
#
# ```python
# mydict = {'a':1, 'b':2, 'a':3}
# ```

# %%
mydict = {'a': 1, 'b': 2, 'c': 3}
print(mydict)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# Explain the error.

# %% [markdown]
# 'a'is repeated twice

# %% [markdown]
# Q27. Add a new key `'grade'` with value `'A'` to the dictionary `student = {'name':'Eve'}`.

# %%
student = {'name': 'Eve'}
student['grade'] = 'A'
print(student)
# Out:
# {'name': 'Eve', 'grade': 'A'}

# %% [markdown]
# Q28. Compare if `15` is greater than `10`.

# %%
print(15>10)
# Out:
# True

# %% [markdown]
# Q29. Fix the error in the following code:
#
# ```python
# if 5 = 5:
#     print('Equal')
# ```

# %%
if 5 == 5:
    print('Equal')
# Out:
# Equal

# %% [markdown]
# Q30. Write a comparison that checks if `x = 7` is not equal to `10`.

# %%
x = 7
print( x != 10)
# Out:
# True

# %% [markdown]
# Q31. Write an if statement that prints 'Positive' if `num > 0`.

# %%
if num > 0:
    print('Positive')
# Out:
# Positive

# %% [markdown]
# Q32. Fix the error in the following code:
#
# ```python
# if x > 10
#     print('Greater than ten')
# ```

# %%
if x > 10:
    print('Greater than ten')

# %% [markdown]
# Q33. Write an if-elif-else statement that:
# - prints 'Zero' if `n == 0`
# - prints 'Positive' if `n > 0`
# - prints 'Negative' otherwise.

# %%
n = 1
if n == 0:
    print('Zero')
elif n > 0:
    print('Positive')
else:
    print('Negative')
# Out:
# Positive

# %% [markdown]
# Q34. What will the following code print?  Answer without running the code first.
#
# ```python
# x = 5
# if x > 10:
#     print('Large')
# elif x > 3:
#     print('Medium')
# else:
#     print('Small')
# ```

# %% [markdown]
# Medium

# %% [markdown]
# Q35. Write a for loop that prints numbers from 1 to 5.

# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Q36. Fix the error in the following code:
#
# ```python
# for i in range(5)
#     print(i)
# ```

# %%
for i in range(5):
    print(i)

# %% [markdown]
# Q37. Write a while loop that prints numbers from 1 to 3.

# %%
i = 1
while i < 4:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3

# %% [markdown]
# Q38. What is wrong with this loop? Fix it.
#
# ```python
# count = 1
# while count < 5:
#     print(count)
# ```

# %%
count = 1
while count < 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# Explain what the error was and how you fixed it.

# %% [markdown]
# It will keep printing 1 continously, as value inside count is not changing, loop runs forever.

# %% [markdown]
# Q39. Write a for loop to iterate through the list `colors = ['red','green','blue']` and print each color.

# %%
colors = ['red', 'green', 'blue']
for color in colors:
    print(color)
# Out:
# red
# green
# blue

# %% [markdown]
# Q40. Use a loop to calculate the sum of numbers in the list `[1,2,3,4,5]`.  Try using both types of loops to see the different ways to do it.

# %%
nums = [1, 2, 3, 4, 5]
total = 0

for num in nums:  
    total += num
print(total)
# Out:
# 15

# %% [markdown]
# # The End

# %%
numbers = [12,32,43]
print(max(numbers))
# Out:
# 43
